# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

driver = webdriver.Chrome()
driver.get('https://www.kurly.com/collections/market-best?page=1&per_page=96&sorted_type=4')
driver.maximize_window()

#driver.execute_script("window.scrollTo(0, document.body.scrollHeight);") 
best_list = driver.find_elements(By.CSS_SELECTOR, 'div.css-11kh0cw.ef36txc5 > a')
name_list = []
price_list = []
reply_cnt_list = []

for item in best_list:
    name = item.find_element(By.CSS_SELECTOR, 'span.css-1dry2r1.e1c07x488').text
    price_temp= item.find_element(By.CSS_SELECTOR, 'span.sales-price.css-18tpqqq.ei5rudb1').text
    price_temp = price_temp.split('원') #원 기준으로 구분
    price = price_temp[0] #숫자만 출력
    reply_cnt = item.find_element(By.CSS_SELECTOR, 'div > span.review-number.css-l610kl.e1c07x480').text
    name_list.append(name)
    price_list.append(price)
    reply_cnt_list.append(reply_cnt)


best_df = pd.DataFrame(columns=['name','price','reply_cnt'],
                         data = zip(name_list,price_list,reply_cnt_list))

best_df
# Out:
# Empty DataFrame
# Columns: [name, price, reply_cnt]
# Index: []

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

driver = webdriver.Chrome()
driver.get('https://www.kurly.com/collections/market-best?page=1&per_page=96&sorted_type=4')
driver.maximize_window()

#driver.execute_script("window.scrollTo(0, document.body.scrollHeight);") 
best_list = driver.find_elements(By.CSS_SELECTOR, 'div.css-11kh0cw.ef36txc5 > a')
name_list = []
price_list = []
reply_cnt_list = []

for item in best_list:
    name = item.find_element(By.CSS_SELECTOR, 'span.css-1dry2r1.e1c07x488').text
    price_temp= item.find_element(By.CSS_SELECTOR, 'span.sales-price.css-18tpqqq.ei5rudb1').text
    price_temp = price_temp.split('원') #원 기준으로 구분
    price = price_temp[0] #숫자만 출력
    reply_cnt = item.find_element(By.CSS_SELECTOR, 'div > span.review-number.css-l610kl.e1c07x480').text
    name_list.append(name)
    price_list.append(price)
    reply_cnt_list.append(reply_cnt)


best_df = pd.DataFrame(columns=['name','price','reply_cnt'],
                         data = zip(name_list,price_list,reply_cnt_list))

best_df
# Out:
# Empty DataFrame
# Columns: [name, price, reply_cnt]
# Index: []

# %%
# 지정된 변수명에 결과를 담아주세요-!
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

driver = webdriver.Chrome()
driver.get('https://www.kurly.com/collections/market-best?page=1&per_page=96&sorted_type=4')
driver.maximize_window()

name_list = []
price_list = []
reply_cnt_list = []

for _ in range(3):
    list_popular = driver.find_elements(By.CSS_SELECTOR, 'div.css-11kh0cw.ef36txc5 > a')
    
    for item in list_popular:
        name = item.find_element(By.CSS_SELECTOR, 'span.css-1dry2r1.e1c07x488').text
        price_temp= item.find_element(By.CSS_SELECTOR, 'span.sales-price.css-18tpqqq.ei5rudb1').text
        price_temp = price_temp.split('원') #원 기준으로 구분
        price = price_temp[0] #숫자만 출력
        reply_cnt = item.find_element(By.CSS_SELECTOR, 'div > span.review-number.css-l610kl.e1c07x480').text
        name_list.append(name)
        price_list.append(price)
        reply_cnt_list.append(reply_cnt)
        driver.find_element(By.XPATH, '//*[@id="container"]/div/div[2]/div[3]/a[6]/img').click() 
   
    

best_df = pd.DataFrame(columns=['name','price','reply_cnt'],
                         data = zip(name_list,price_list,reply_cnt_list))
 
best_df
# Out:
# Empty DataFrame
# Columns: [name, price, reply_cnt]
# Index: []

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

driver = webdriver.Chrome()
driver.get('https://www.kurly.com/collections/market-best?page=1&per_page=96&sorted_type=4')
driver.maximize_window()

#driver.execute_script("window.scrollTo(0, document.body.scrollHeight);") 
best_list = driver.find_elements(By.CSS_SELECTOR, 'div.css-11kh0cw.ef36txc5 > a')
name_list = []
price_list = []
reply_cnt_list = []
kurly_only_list = []

for item in best_list:
    if item.get_attribute('id')=='popular-ad':
            pass
        else:
    name = item.find_element(By.CSS_SELECTOR, 'span.css-1dry2r1.e1c07x488').text
    price_temp= item.find_element(By.CSS_SELECTOR, 'span.sales-price.css-18tpqqq.ei5rudb1').text
    price_temp = price_temp.split('원') #원 기준으로 구분
    price = price_temp[0] #숫자만 출력
    reply_cnt = item.find_element(By.CSS_SELECTOR, 'div > span.review-number.css-l610kl.e1c07x480').text
    kurly_only= item.find_element(By.CSS_SELECTOR, 'span.css-1e5t2sz.e1cvv2hm0').text
    name_list.append(name)
    price_list.append(price)
    reply_cnt_list.append(reply_cnt)
    kurly_only_list.append(kurly_only)


best_df = pd.DataFrame(columns=['name','price','reply_cnt','kurly_only'],
                         data = zip(name_list,price_list,reply_cnt_list,kurly_only_list))

best_df
# Out:
# Empty DataFrame
# Columns: [name, price, reply_cnt, kurly_only]
# Index: []

# %%
is_review_count = select_book.select_one('em.txC_blue')

if is_review_count != None:
        review_count = int(select_book.select_one('em.txC_blue').text)
    else:
        review_count = 0

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

driver = webdriver.Chrome()
driver.get('https://www.kurly.com/collections/market-best?page=1&per_page=96&sorted_type=4')
driver.maximize_window()

#driver.execute_script("window.scrollTo(0, document.body.scrollHeight);") 
best_list = driver.find_elements(By.CSS_SELECTOR, 'div.css-11kh0cw.ef36txc5 > a')
best_df = pd.DataFrame(columns=['name','price','reply_cnt','kurly_only'])
    
for item in best_list:
    name = item.find_element(By.CSS_SELECTOR, 'span.css-1dry2r1.e1c07x488').text
    price_temp= item.find_element(By.CSS_SELECTOR, 'span.sales-price.css-18tpqqq.ei5rudb1').text
    price_temp = price_temp.split('원') #원 기준으로 구분
    price = price_temp[0] #숫자만 출력
    reply_cnt = item.find_element(By.CSS_SELECTOR, 'div > span.review-number.css-l610kl.e1c07x480').text
    
    is_kurly_only = item.find_element(By.CSS_SELECTOR, 'div > span.css-1e5t2sz.e1cvv2hm0')
    if  is_kurly_only != None : 
            kurly_only  = item.find_element(By.CSS_SELECTOR, 'div > span.css-1e5t2sz.e1cvv2hm0').text
    else :
            kurly_only = ''
    best_df.loc[name] = [price,reply_cnt,kurly_only]
best_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/yeon/Desktop/크롤링스터디/컬리.ipynb 셀 6 line 2
#      <a href='vscode-notebook-cell:/Users/yeon/Desktop/%E1%84%8F%E1%85%B3%E1%84%85%E1%85%A9%E1%86%AF%E1%84%85%E1%85%B5%E1%86%BC%E1%84%89%E1%85%B3%E1%84%90%E1%85%A5%E1%84%83%E1%85%B5/%E1%84%8F%E1%85%A5%E1%86%AF%E1%84%85%E1%85%B5.ipynb#W5sZmlsZQ%3D%3D?line=22'>23</a>     else :
#      <a href='vscode-notebook-cell:/Users/yeon/Desktop/%E1%84%8F%E1%85%B3%E1%84%85%E1%85%A9%E1%86%AF%E1%84%85%E1%85%B5%E1%86%BC%E1%84%89%E1%85%B3%E1%84%90%E1%85%A5%E1%84%83%E1%85%B5/%E1%84%8F%E1%85%A5%E1%86%AF%E1%84%85%E1%85%B5.ipynb#W5sZmlsZQ%3D%3D?line=23'>24</a>             kurly_only = ''
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

driver = webdriver.Chrome()
driver.get('https://www.kurly.com/collections/market-best?page=1&per_page=96&sorted_type=4')
driver.maximize_window()

#driver.execute_script("window.scrollTo(0, document.body.scrollHeight);") 
best_list = driver.find_elements(By.CSS_SELECTOR, 'div.css-11kh0cw.ef36txc5 > a')
name_list = []
price_list = []
reply_cnt_list = []
kurly_only_list = []
    
for item in best_list:
    name = item.find_element(By.CSS_SELECTOR, 'span.css-1dry2r1.e1c07x488').text
    price_temp= item.find_element(By.CSS_SELECTOR, 'span.sales-price.css-18tpqqq.ei5rudb1').text
    price_temp = price_temp.split('원') #원 기준으로 구분
    price = price_temp[0] #숫자만 출력
    reply_cnt = item.find_element(By.CSS_SELECTOR, 'div > span.review-number.css-l610kl.e1c07x480').text
    name_list.append(name)
    price_list.append(price)
    reply_cnt_list.append(reply_cnt)
    
    is_kurly_only = item.find_element(By.CSS_SELECTOR, 'div > span.css-1e5t2sz.e1cvv2hm0')
    if  is_kurly_only != None : 
            kurly_only  = item.find_element(By.CSS_SELECTOR, 'div > span.css-1e5t2sz.e1cvv2hm0').text
    else :
            kurly_only = ''
    kurly_only_list.append(kurly_only)
best_df
# Out:
# Empty DataFrame
# Columns: [name, price, reply_cnt]
# Index: []
